# %%
! pip install tensorflow

# %%
! pip install deepcut
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 12.8 MB/s eta 0:00:00
# ...

# %%
! pip install --upgrade gdown
# Out:
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.7.3
#     Uninstalling gdown-4.7.3:
#       Successfully uninstalled gdown-4.7.3
# ...

# %%
#https://drive.google.com/file/d/1FV2X8vxcChvs0mPHl5B6XSWus35LQ9fp/view?usp=sharing
! gdown --id 1FV2X8vxcChvs0mPHl5B6XSWus35LQ9fp
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1FV2X8vxcChvs0mPHl5B6XSWus35LQ9fp
# To: /content/Prob.csv
# 100% 13.8k/13.8k [00:00<00:00, 34.1MB/s]

# %%
import pandas as pd
data = pd.read_csv('/content/Prob.csv')

# %%
data
# Out:
#      id                                               text  \
# 0     3                          รถชนกันก่อนข้ามสะพานคลอง1
# 1     5         ตอนนี้ท้ายแถวติดมาถึงคลอง 4 แล้วค่ะ ติดมาก
# 2     8  ติดตั้งแต่คลอง4 ตอน6:40 จนตอนนี้ 7:30ยังไม่ถึง...
# 3    13  เมื่อวานก็อุบัติเหตุหน้าคลอง 1 ขับกันยังไงครับ...
# 4    16           ติดหนักมากค่ะ หนีไปเลียบคลองหนักกว่าเดิม
# 5    17                                 ติดมากๆยันคลอง​สี่
# 6    22                             ติดยาวเลยคลอง4 แล้วค่ะ
# 7    29  เสร็จแล้วน่าจะดีขึ้นครับ ให้ดีย้ายป้ายรถเมล์ไป...
# 8    31  ว่าแล้วทำไมวันนี้รถติดแปลกๆ ติดแบบไม่ขยับ พอมา...
# 9    43  สายคลองวันนี้เกิดอะไรขึ้นคะติดผิดปกติ เหมือนมี...
# 10   46     งานเข้า8โมงแต่ตอนนี้ยังไม่ถึงสะพานคลอง2เบย5555
# 11   48  ตอนนี้หม้อแปลงระเบิดตรงสะพานกรีนสปอต แสงไฟวาบส...
# 12   49  เมื่อออกจากบ้าน 6.30ถึงฟิว07.10 ออกจากฟิวเยียบ...
# 13   51  ออกมา 07ใ30 จากสะพานแดงไม่ติดเท่าไร ไม่เห็นอุบ...
# 14   54  การจราจร 8.30 น คลอง1 รถมากแต่ไหลเรื่อยๆครับ ข...
# ...

# %%
text = []
for i in data['text']:
  text.append(i)

# %%
import deepcut
token = []
for i in text:
  words = deepcut.tokenize(i)
  token.append(words)
  print(words)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# ['รถ', 'ชน', 'กัน', 'ก่อน', 'ข้าม', 'สะพาน', 'คลอง1']
# 2/2 [==============================] - 0s 12ms/step
# ['ตอน', 'นี้', 'ท้าย', 'แถว', 'ติด', 'มา', 'ถึง', 'คลอง', ' ', '4', ' ', 'แล้ว', 'ค่ะ', ' ', 'ติด', 'มาก']
# 2/2 [==============================] - 0s 15ms/step
# ['ติด', 'ตั้งแต่', 'คลอง', '4', ' ', 'ตอน', '6', ':', '40', ' ', 'จน', 'ตอน', 'นี้', ' ', '7', ':', '30', 'ยัง', 'ไม่', 'ถึง', 'คลอง', '2', 'เลย', 'ค่ะ']
# 3/3 [==============================] - 0s 10ms/step
# ['เมื่อ', 'วาน', 'ก็', 'อุบัติเหตุ', 'หน้า', 'คลอง', ' ', '1', ' ', 'ขับ', 'กัน', 'ยัง', 'ไง', 'ครับ', 'เนี่ยย', ' ', 'ชน', 'กัน', ' ', '2', ' ', 'วัน', 'ติด']
# 2/2 [==============================] - 0s 11ms/step
# ['ติด', 'หนัก', 'มาก', 'ค่ะ', ' ', 'หนี', 'ไป', 'เลียบ', 'คลอง', 'หนัก', 'กว่า', 'เดิม']
# 1/1 [==============================] - 0s 28ms/step
# ['ติด', 'มาก', 'ๆ', 'ยัน', 'คลอง', '\u200bสี่']
# ...

# %%
data['token'] = token

# %%
data
# Out:
#      id                                               text  \
# 0     3                          รถชนกันก่อนข้ามสะพานคลอง1
# 1     5         ตอนนี้ท้ายแถวติดมาถึงคลอง 4 แล้วค่ะ ติดมาก
# 2     8  ติดตั้งแต่คลอง4 ตอน6:40 จนตอนนี้ 7:30ยังไม่ถึง...
# 3    13  เมื่อวานก็อุบัติเหตุหน้าคลอง 1 ขับกันยังไงครับ...
# 4    16           ติดหนักมากค่ะ หนีไปเลียบคลองหนักกว่าเดิม
# 5    17                                 ติดมากๆยันคลอง​สี่
# 6    22                             ติดยาวเลยคลอง4 แล้วค่ะ
# 7    29  เสร็จแล้วน่าจะดีขึ้นครับ ให้ดีย้ายป้ายรถเมล์ไป...
# 8    31  ว่าแล้วทำไมวันนี้รถติดแปลกๆ ติดแบบไม่ขยับ พอมา...
# 9    43  สายคลองวันนี้เกิดอะไรขึ้นคะติดผิดปกติ เหมือนมี...
# 10   46     งานเข้า8โมงแต่ตอนนี้ยังไม่ถึงสะพานคลอง2เบย5555
# 11   48  ตอนนี้หม้อแปลงระเบิดตรงสะพานกรีนสปอต แสงไฟวาบส...
# 12   49  เมื่อออกจากบ้าน 6.30ถึงฟิว07.10 ออกจากฟิวเยียบ...
# 13   51  ออกมา 07ใ30 จากสะพานแดงไม่ติดเท่าไร ไม่เห็นอุบ...
# 14   54  การจราจร 8.30 น คลอง1 รถมากแต่ไหลเรื่อยๆครับ ข...
# ...

# %%
data.to_excel('d1.xlsx')
